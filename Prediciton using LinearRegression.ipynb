# %% [markdown]
# # Prediction using LinearRegression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sklearn

# %%
dataset=pd.read_csv(r"C:\Users\saran\Downloads\Machine-learning-main\Machine-learning-main\heart_failure_clinical_records_dataset.csv")
dataset
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
dataset.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
dataset.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
dataset=pd.read_csv(r"C:\Users\saran\Downloads\Machine-learning-main\Machine-learning-main\heart_failure_clinical_records_dataset.csv")
x= dataset.iloc[:, :-1].values
y= dataset.iloc[:, :-1].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=1/3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)
y_pred
# Out:
# array([[ 4.00000000e+01,  1.00000000e+00,  1.01000000e+02, ...,
#          6.52423362e-15, -4.27557273e-15,  1.87000000e+02],
#        [ 6.06670000e+01,  1.00000000e+00,  1.51000000e+02, ...,
#          9.39520581e-15, -8.37267565e-15,  1.72000000e+02],
#        [ 4.50000000e+01,  1.00000000e+00,  9.81000000e+02, ...,
#          1.00000000e+00, -1.52381334e-14,  1.10000000e+01],
#        ...,
#        [ 6.00000000e+01,  1.00000000e+00,  2.60000000e+02, ...,
#         -1.09313896e-15,  1.00000000e+00,  4.50000000e+01],
#        [ 5.90000000e+01,  1.00000000e+00,  1.76000000e+02, ...,
#          1.00000000e+00,  1.00000000e+00,  1.50000000e+02],
#        [ 7.00000000e+01,  1.00000000e+00,  1.25000000e+02, ...,
#          5.94655936e-15, -2.47044828e-15,  1.50000000e+01]])

# %%
#VISUALSING THE TRAINING SET RESULTS

plt.scatter(x_train,y_train,color="red")
plt.plot(x_train,regressor.predict(x_train),color="blue")
plt.title('age VS high_blood_pressure  {Training_set}')
plt.xlabel('high_blood_pressure')
plt.ylabel('age')
plt.show()

# %%
#Visualising the Test Set results

plt.scatter(x_test, y_test, color = 'green')
plt.plot(x_train, regressor.predict(x_train), color = 'red')
plt.title('age VS high_blood_pressure {test_set}',color='blue')
plt.xlabel('high_blood_pressure',color='purple')
plt.ylabel('age',color='purple')
plt.show()

# %%
plt.scatter(dataset['age'], dataset['platelets'])
plt.title('SCATTER PLOT OF AGE VS platelets')
plt.xlabel('PLATELETS')
plt.ylabel('age')
# Out:
# Text(0, 0.5, 'age')

# %%
plt.bar(dataset['age'], dataset['platelets'])
plt.title('BAR PLOT')
plt.xlabel('PLATELETS')
plt.ylabel('AGE')
# Out:
# Text(0, 0.5, 'AGE')
